# %% [markdown]
# **Experimentation on using hand-crafted features for performing Automatic Signature Verification**
#
# Use a custom feature space made out of:
# * The Perceptual Hash of an Image
# * Aspect Ratio
# * Convex Hull Area/Bounding Box Area
# * Contour Area/Bounding Box Area
#
# We now feed these features to a standard classifier.

# %% [markdown]
# ##### Import Libraries

# %%
import cv2
import imagehash
import numpy as np
import os
from os import listdir
from pylab import *
from PIL import Image
from scipy.cluster.vq import *
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
from sklearn import tree, svm, linear_model
from sklearn.metrics import confusion_matrix
from imageio import imread

# %%
genuine_images_path = "./BHSig260modified/genuine"
forged_images_path = "./BHSig260modified/forged"

genuine_image_filenames = listdir(genuine_images_path)
forged_image_filenames = listdir(forged_images_path)

# %%
genuine_image_features = [[] for x in range(273)]
forged_image_features = [[] for x in range(273)]

for name in genuine_image_filenames:
    signature_id = int(name.split('_')[0][-3:])
    genuine_image_features[signature_id - 1].append({"name": name})

for name in forged_image_filenames:
    signature_id = int(name.split('_')[0][-3:])
    forged_image_features[signature_id - 1].append({"name": name})

# %%
def preprocess_image(image_path, display=False):
    """
    1) Convert image to gray scale
    2) Threshold image

    :param image_path: image path
    :param display: flag - if true display images
    :return: preprocessed image
    """
    raw_image = imread(image_path)
    if len(raw_image.shape)<3:
        bw_image = 255-raw_image
    else:
        bw_image = cv2.cvtColor(raw_image, cv2.COLOR_BGR2GRAY)
        bw_image = 255 - bw_image

    if display:
        plt.figure(figsize = [8,8])
        plt.imshow(bw_image, cm='gray')
        plt.axis('off')
        plt.show()

    _, threshold_image = cv2.threshold(bw_image, 30, 255, 0)

    if display:
        plt.figure(figsize = [8,8])
        plt.imshow(threshold_image, cmap='gray')
        plt.axis('off')
        plt.show()

    return threshold_image

# %%
def get_contour_features(preprocessed_image, display=False):
    """
    :param preprocessed_image: preprocessed image
    :param display: flag - if true display images
    :return: aspect ratio of bounding rectangle, area of bounding rectangle, contours and convex hull
    """

    rect = cv2.minAreaRect(cv2.findNonZero(preprocessed_image))
    box = cv2.boxPoints(rect)
    box = np.int0(box)

    w = np.linalg.norm(box[0] - box[1])
    h = np.linalg.norm(box[1] - box[2])

    aspect_ratio = max(w, h) / min(w, h)
    bounding_rect_area = w * h

    if display:
        image1 = cv2.drawContours(preprocessed_image.copy(), [box], 0, (120, 120, 120), 2)
        plt.figure(figsize = [8,8])
        plt.imshow(cv2.resize(image1, (0, 0), fx=2.5, fy=2.5),cmap = 'gray')
        plt.axis('off')
        plt.show()

    hull = cv2.convexHull(cv2.findNonZero(preprocessed_image))

    if display:
        convex_hull_image = cv2.drawContours(preprocessed_image.copy(), [hull], 0, (120, 120, 120), 2)
        plt.figure(figsize = [8,8])
        plt.imshow(cv2.resize(convex_hull_image, (0, 0), fx=2.5, fy=2.5),cmap='gray')
        plt.axis('off')
        plt.show()

    _, contours, hierarchy = cv2.findContours(preprocessed_image.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    if display:
        contour_image = cv2.drawContours(preprocessed_image.copy(), contours, -1, (120, 120, 120), 3)
        plt.figure(figsize = [8,8])
        plt.imshow(cv2.resize(contour_image, (0, 0), fx=2.5, fy=2.5), cmap = 'gray')
        plt.axis('off')
        plt.show()


    contour_area = 0
    for cnt in contours:
        contour_area += cv2.contourArea(cnt)
    hull_area = cv2.contourArea(hull)

    return aspect_ratio, bounding_rect_area, hull_area, contour_area

# %%
def sift(preprocessed_image, image_path, display=False):
    raw_image = cv2.imread(image_path)
    sift = cv2.xfeatures2d.SIFT_create()
    kp, des = sift.detectAndCompute(preprocessed_image, None)

    if display:
        cv2.drawKeypoints(preprocessed_image, kp, raw_image)
        plt.figure(figsize = [8,8])
        plt.imshow(cv2.resize(raw_image, (0, 0), fx=3, fy=3))
        plt.axis('off')
        plt.show()

    return (image_path, des)

# %%
def run(clsf):
    des_list = []
    true_positive = 0
    true_negative = 0
    false_positive = 0
    false_negative = 0
    im_contour_features = []
    display = False

    for i in range(273):
        print('Learning '+str(i+1)+'th image')
        des_list = []
        for im in genuine_image_features[i]:
            image_path = genuine_images_path + "/" + im['name']
            preprocessed_image = preprocess_image(image_path)
            hash = imagehash.phash(Image.open(image_path))

            aspect_ratio, bounding_rect_area, convex_hull_area, contours_area = get_contour_features(preprocessed_image.copy(), display=display)

            hash = int(str(hash), 16)
            im['hash'] = hash
            im['aspect_ratio'] = aspect_ratio
            im['hull_area/bounding_area'] = convex_hull_area / bounding_rect_area
            im['contour_area/bounding_area'] = contours_area / bounding_rect_area

            im_contour_features.append([hash, aspect_ratio, convex_hull_area / bounding_rect_area, contours_area / bounding_rect_area])

            des_list.append(sift(preprocessed_image, image_path))
    
        if len(des_list)==0:
#             print(image_path+' does not have suffiecient features, skipping')
            pass
    
        for im in forged_image_features[i]:
            image_path = forged_images_path + "/" + im['name']
            preprocessed_image = preprocess_image(image_path)
            hash = imagehash.phash(Image.open(image_path))

            aspect_ratio, bounding_rect_area, convex_hull_area, contours_area = get_contour_features(preprocessed_image.copy(), display=display)

            hash = int(str(hash), 16)
            im['hash'] = hash
            im['aspect_ratio'] = aspect_ratio
            im['hull_area/bounding_area'] = convex_hull_area / bounding_rect_area
            im['contour_area/bounding_area'] = contours_area / bounding_rect_area

            im_contour_features.append([hash, aspect_ratio, convex_hull_area / bounding_rect_area, contours_area / bounding_rect_area])

            des_list.append(sift(preprocessed_image, image_path))
    
        if len(des_list)==0:
#             print(image_path+' does not have suffiecient features, skipping')
            continue
        descriptors = des_list[0][1]
        for image_path, descriptor in des_list[1:]:
            descriptors = np.vstack((descriptors, descriptor))
        k = 170
        voc, variance = kmeans(descriptors, k, 1)

        # Calculate the histogram of features
        im_features = np.zeros((len(genuine_image_features[i]) + len(forged_image_features[i]), k + 4), "float32")
        for i in range(len(genuine_image_features[i]) + len(forged_image_features[i])):
            words, distance = vq(des_list[i][1], voc)
            for w in words:
                im_features[i][w] += 1

            for j in range(4):
                im_features[i][k + j] = im_contour_features[i][j]

        # nbr_occurences = np.sum((im_features > 0) * 1, axis=0)
        # idf = np.array(np.log((1.0 * len(image_paths) + 1) / (1.0 * nbr_occurences + 1)), 'float32')

        # Scaling the words
        stdSlr = StandardScaler().fit(im_features)
        im_features = stdSlr.transform(im_features)

        train_genuine_features, test_genuine_features = im_features[0:3], im_features[3:5]

        train_forged_features, test_forged_features = im_features[5:8], im_features[8:10]
        clf = clsf
#     clf = linear_model.LogisticRegression(C=1e5)
    
#     clf = tree.DecisionTreeClassifier()
#     clf = tree.DecisionTreeRegressor()
#     clf = svm.SVC()

        clf.fit(np.concatenate((train_forged_features, train_genuine_features)),np.array([1 for x in range(len(train_forged_features))] + [2 for x in range(len(train_genuine_features))]))

        genuine_res = clf.predict(test_genuine_features)

        for res in genuine_res:
            if int(res) == 2:
                true_positive += 1
            else:
                false_negative += 1

        forged_res = clf.predict(test_forged_features)

        for res in forged_res:
            if int(res) == 1:
                true_negative += 1
            else:
                false_positive += 1
            
#         print('-----------------------------------------------')
    print('Completed Learning')
    print(' ')
    accuracy = float(true_positive + true_negative) / (true_positive + true_negative + false_negative + false_positive)
    precision = float(true_positive) / (true_positive + false_positive)
    recall = float(true_positive) / (true_positive + false_negative)
    far = float(false_positive) / (false_positive + true_negative)
    frr = float(false_negative) / (false_negative + true_positive)
    f1_score = float(2 * precision * recall) / (precision + recall)
    print('Stats')
    print(' ')
    print("True Positives: ", true_positive)
    print("True Negatives: ", true_negative)
    print("False Positives: ", false_positive)
    print("False Negatives: ", false_negative)
    print("Accuracy: ", round(accuracy, 2))
    print("Precision: ", round(precision, 2))
    print("Recall: ", round(recall, 2))
    print("FAR: ",round(far, 2))
    print("FRR: ",round(frr, 2))
    print("F1 score: ", round(f1_score, 2))

# %% [markdown]
# ##### Linear SVC()

# %%
clsf = LinearSVC()
run(clsf)
# Out:
# Learning 1th image
# Learning 2th image
# Learning 3th image
# Learning 4th image
# Learning 5th image
# Learning 6th image
# Learning 7th image
# Learning 8th image
# Learning 9th image
# Learning 10th image
# Learning 11th image
# Learning 12th image
# Learning 13th image
# Learning 14th image
# Learning 15th image
# Learning 16th image
# Learning 17th image
# Learning 18th image
# Learning 19th image
# Learning 20th image
# Learning 21th image
# Learning 22th image
# Learning 23th image
# Learning 24th image
# Learning 25th image
# Learning 26th image
# Learning 27th image
# Learning 28th image
# Learning 29th image
# Learning 30th image
# Learning 31th image
# Learning 32th image
# Learning 33th image
# Learning 34th image
# Learning 35th image
# Learning 36th image
# Learning 37th image
# Learning 38th image
# Learning 39th image
# Learning 40th image
# Learning 41th image
# Learning 42th image
# Learning 43th image
# Learning 44th image
# Learning 45th image
# Learning 46th image
# Learning 47th image
# Learning 48th image
# Learning 49th image
# Learning 50th image
# Learning 51th image
# Learning 52th image
# Learning 53th image
# Learning 54th image
# Learning 55th image
# Learning 56th image
# Learning 57th image
# Learning 58th image
# Learning 59th image
# Learning 60th image
# Learning 61th image
# Learning 62th image
# Learning 63th image
# Learning 64th image
# Learning 65th image
# Learning 66th image
# Learning 67th image
# Learning 68th image
# Learning 69th image
# Learning 70th image
# Learning 71th image
# Learning 72th image
# Learning 73th image
# Learning 74th image
# Learning 75th image
# Learning 76th image
# Learning 77th image
# Learning 78th image
# Learning 79th image
# Learning 80th image
# Learning 81th image
# Learning 82th image
# Learning 83th image
# Learning 84th image
# Learning 85th image
# Learning 86th image
# Learning 87th image
# Learning 88th image
# Learning 89th image
# Learning 90th image
# Learning 91th image
# Learning 92th image
# Learning 93th image
# Learning 94th image
# Learning 95th image
# Learning 96th image
# Learning 97th image
# Learning 98th image
# Learning 99th image
# Learning 100th image
# Learning 101th image
# Learning 102th image
# Learning 103th image
# Learning 104th image
# Learning 105th image
# Learning 106th image
# Learning 107th image
# Learning 108th image
# Learning 109th image
# Learning 110th image
# Learning 111th image
# Learning 112th image
# Learning 113th image
# Learning 114th image
# Learning 115th image
# Learning 116th image
# Learning 117th image
# Learning 118th image
# Learning 119th image
# Learning 120th image
# Learning 121th image
# Learning 122th image
# Learning 123th image
# Learning 124th image
# Learning 125th image
# Learning 126th image
# Learning 127th image
# Learning 128th image
# Learning 129th image
# Learning 130th image
# Learning 131th image
# Learning 132th image
# Learning 133th image
# Learning 134th image
# Learning 135th image
# Learning 136th image
# Learning 137th image
# Learning 138th image
# Learning 139th image
# Learning 140th image
# Learning 141th image
# Learning 142th image
# Learning 143th image
# Learning 144th image
# Learning 145th image
# Learning 146th image
# Learning 147th image
# Learning 148th image
# Learning 149th image
# Learning 150th image
# Learning 151th image
# Learning 152th image
# Learning 153th image
# Learning 154th image
# Learning 155th image
# Learning 156th image
# Learning 157th image
# Learning 158th image
# Learning 159th image
# Learning 160th image
# Learning 161th image
# Learning 162th image
# Learning 163th image
# Learning 164th image
# Learning 165th image
# Learning 166th image
# Learning 167th image
# Learning 168th image
# Learning 169th image
# Learning 170th image
# Learning 171th image
# Learning 172th image
# Learning 173th image
# Learning 174th image
# Learning 175th image
# Learning 176th image
# Learning 177th image
# Learning 178th image
# Learning 179th image
# Learning 180th image
# Learning 181th image
# Learning 182th image
# Learning 183th image
# Learning 184th image
# Learning 185th image
# Learning 186th image
# Learning 187th image
# Learning 188th image
# Learning 189th image
# Learning 190th image
# Learning 191th image
# Learning 192th image
# Learning 193th image
# Learning 194th image
# Learning 195th image
# Learning 196th image
# Learning 197th image
# Learning 198th image
# Learning 199th image
# Learning 200th image
# Learning 201th image
# Learning 202th image
# Learning 203th image
# Learning 204th image
# Learning 205th image
# Learning 206th image
# Learning 207th image
# Learning 208th image
# Learning 209th image
# Learning 210th image
# Learning 211th image
# Learning 212th image
# Learning 213th image
# Learning 214th image
# Learning 215th image
# Learning 216th image
# Learning 217th image
# Learning 218th image
# Learning 219th image
# Learning 220th image
# Learning 221th image
# Learning 222th image
# Learning 223th image
# Learning 224th image
# Learning 225th image
# Learning 226th image
# Learning 227th image
# Learning 228th image
# Learning 229th image
# Learning 230th image
# Learning 231th image
# Learning 232th image
# Learning 233th image
# Learning 234th image
# Learning 235th image
# Learning 236th image
# Learning 237th image
# Learning 238th image
# Learning 239th image
# Learning 240th image
# Learning 241th image
# Learning 242th image
# Learning 243th image
# Learning 244th image
# Learning 245th image
# Learning 246th image
# Learning 247th image
# Learning 248th image
# Learning 249th image
# Learning 250th image
# Learning 251th image
# Learning 252th image
# Learning 253th image
# Learning 254th image
# Learning 255th image
# Learning 256th image
# Learning 257th image
# Learning 258th image
# Learning 259th image
# Learning 260th image
# Learning 261th image
# Learning 262th image
# Learning 263th image
# Learning 264th image
# Learning 265th image
# Learning 266th image
# Learning 267th image
# Learning 268th image
# Learning 269th image
# Learning 270th image
# Learning 271th image
# Learning 272th image
# Learning 273th image
# Completed Learning
#
# Stats
#
# True Positives:  288
# True Negatives:  287
# False Positives:  257
# False Negatives:  256
# Accuracy:  0.53
# Precision:  0.53
# Recall:  0.53
# FAR:  0.47
# FRR:  0.47
# F1 score:  0.53

# %% [markdown]
# ##### Logistic Regression

# %%
clsf = linear_model.LogisticRegression(C=1e5)
run(clsf)
# Out:
# Learning 1th image
# Learning 2th image
# Learning 3th image
# Learning 4th image
# Learning 5th image
# Learning 6th image
# Learning 7th image
# Learning 8th image
# Learning 9th image
# Learning 10th image
# Learning 11th image
# Learning 12th image
# Learning 13th image
# Learning 14th image
# Learning 15th image
# Learning 16th image
# Learning 17th image
# Learning 18th image
# Learning 19th image
# Learning 20th image
# Learning 21th image
# Learning 22th image
# Learning 23th image
# Learning 24th image
# Learning 25th image
# Learning 26th image
# Learning 27th image
# Learning 28th image
# Learning 29th image
# Learning 30th image
# Learning 31th image
# Learning 32th image
# Learning 33th image
# Learning 34th image
# Learning 35th image
# Learning 36th image
# Learning 37th image
# Learning 38th image
# Learning 39th image
# Learning 40th image
# Learning 41th image
# Learning 42th image
# Learning 43th image
# Learning 44th image
# Learning 45th image
# Learning 46th image
# Learning 47th image
# Learning 48th image
# Learning 49th image
# Learning 50th image
# Learning 51th image
# Learning 52th image
# Learning 53th image
# Learning 54th image
# Learning 55th image
# Learning 56th image
# Learning 57th image
# Learning 58th image
# Learning 59th image
# Learning 60th image
# Learning 61th image
# Learning 62th image
# Learning 63th image
# Learning 64th image
# Learning 65th image
# Learning 66th image
# Learning 67th image
# Learning 68th image
# Learning 69th image
# Learning 70th image
# Learning 71th image
# Learning 72th image
# Learning 73th image
# Learning 74th image
# Learning 75th image
# Learning 76th image
# Learning 77th image
# Learning 78th image
# Learning 79th image
# Learning 80th image
# Learning 81th image
# Learning 82th image
# Learning 83th image
# Learning 84th image
# Learning 85th image
# Learning 86th image
# Learning 87th image
# Learning 88th image
# Learning 89th image
# Learning 90th image
# Learning 91th image
# Learning 92th image
# Learning 93th image
# Learning 94th image
# Learning 95th image
# Learning 96th image
# Learning 97th image
# Learning 98th image
# Learning 99th image
# Learning 100th image
# Learning 101th image
# Learning 102th image
# Learning 103th image
# Learning 104th image
# Learning 105th image
# Learning 106th image
# Learning 107th image
# Learning 108th image
# Learning 109th image
# Learning 110th image
# Learning 111th image
# Learning 112th image
# Learning 113th image
# Learning 114th image
# Learning 115th image
# Learning 116th image
# Learning 117th image
# Learning 118th image
# Learning 119th image
# Learning 120th image
# Learning 121th image
# Learning 122th image
# Learning 123th image
# Learning 124th image
# Learning 125th image
# Learning 126th image
# Learning 127th image
# Learning 128th image
# Learning 129th image
# Learning 130th image
# Learning 131th image
# Learning 132th image
# Learning 133th image
# Learning 134th image
# Learning 135th image
# Learning 136th image
# Learning 137th image
# Learning 138th image
# Learning 139th image
# Learning 140th image
# Learning 141th image
# Learning 142th image
# Learning 143th image
# Learning 144th image
# Learning 145th image
# Learning 146th image
# Learning 147th image
# Learning 148th image
# Learning 149th image
# Learning 150th image
# Learning 151th image
# Learning 152th image
# Learning 153th image
# Learning 154th image
# Learning 155th image
# Learning 156th image
# Learning 157th image
# Learning 158th image
# Learning 159th image
# Learning 160th image
# Learning 161th image
# Learning 162th image
# Learning 163th image
# Learning 164th image
# Learning 165th image
# Learning 166th image
# Learning 167th image
# Learning 168th image
# Learning 169th image
# Learning 170th image
# Learning 171th image
# Learning 172th image
# Learning 173th image
# Learning 174th image
# Learning 175th image
# Learning 176th image
# Learning 177th image
# Learning 178th image
# Learning 179th image
# Learning 180th image
# Learning 181th image
# Learning 182th image
# Learning 183th image
# Learning 184th image
# Learning 185th image
# Learning 186th image
# Learning 187th image
# Learning 188th image
# Learning 189th image
# Learning 190th image
# Learning 191th image
# Learning 192th image
# Learning 193th image
# Learning 194th image
# Learning 195th image
# Learning 196th image
# Learning 197th image
# Learning 198th image
# Learning 199th image
# Learning 200th image
# Learning 201th image
# Learning 202th image
# Learning 203th image
# Learning 204th image
# Learning 205th image
# Learning 206th image
# Learning 207th image
# Learning 208th image
# Learning 209th image
# Learning 210th image
# Learning 211th image
# Learning 212th image
# Learning 213th image
# Learning 214th image
# Learning 215th image
# Learning 216th image
# Learning 217th image
# Learning 218th image
# Learning 219th image
# Learning 220th image
# Learning 221th image
# Learning 222th image
# Learning 223th image
# Learning 224th image
# Learning 225th image
# Learning 226th image
# Learning 227th image
# Learning 228th image
# Learning 229th image
# Learning 230th image
# Learning 231th image
# Learning 232th image
# Learning 233th image
# Learning 234th image
# Learning 235th image
# Learning 236th image
# Learning 237th image
# Learning 238th image
# Learning 239th image
# Learning 240th image
# Learning 241th image
# Learning 242th image
# Learning 243th image
# Learning 244th image
# Learning 245th image
# Learning 246th image
# Learning 247th image
# Learning 248th image
# Learning 249th image
# Learning 250th image
# Learning 251th image
# Learning 252th image
# Learning 253th image
# Learning 254th image
# Learning 255th image
# Learning 256th image
# Learning 257th image
# Learning 258th image
# Learning 259th image
# Learning 260th image
# Learning 261th image
# Learning 262th image
# Learning 263th image
# Learning 264th image
# Learning 265th image
# Learning 266th image
# Learning 267th image
# Learning 268th image
# Learning 269th image
# Learning 270th image
# Learning 271th image
# Learning 272th image
# Learning 273th image
# Completed Learning
#
# Stats
#
# True Positives:  298
# True Negatives:  284
# False Positives:  260
# False Negatives:  246
# Accuracy:  0.53
# Precision:  0.53
# Recall:  0.55
# FAR:  0.48
# FRR:  0.45
# F1 score:  0.54

# %% [markdown]
# ##### Decision Tree Classifier

# %%
clsf = tree.DecisionTreeClassifier()
run(clsf)
# Out:
# Learning 1th image
# Learning 2th image
# Learning 3th image
# Learning 4th image
# Learning 5th image
# Learning 6th image
# Learning 7th image
# Learning 8th image
# Learning 9th image
# Learning 10th image
# Learning 11th image
# Learning 12th image
# Learning 13th image
# Learning 14th image
# Learning 15th image
# Learning 16th image
# Learning 17th image
# Learning 18th image
# Learning 19th image
# Learning 20th image
# Learning 21th image
# Learning 22th image
# Learning 23th image
# Learning 24th image
# Learning 25th image
# Learning 26th image
# Learning 27th image
# Learning 28th image
# Learning 29th image
# Learning 30th image
# Learning 31th image
# Learning 32th image
# Learning 33th image
# Learning 34th image
# Learning 35th image
# Learning 36th image
# Learning 37th image
# Learning 38th image
# Learning 39th image
# Learning 40th image
# Learning 41th image
# Learning 42th image
# Learning 43th image
# Learning 44th image
# Learning 45th image
# Learning 46th image
# Learning 47th image
# Learning 48th image
# Learning 49th image
# Learning 50th image
# Learning 51th image
# Learning 52th image
# Learning 53th image
# Learning 54th image
# Learning 55th image
# Learning 56th image
# Learning 57th image
# Learning 58th image
# Learning 59th image
# Learning 60th image
# Learning 61th image
# Learning 62th image
# Learning 63th image
# Learning 64th image
# Learning 65th image
# Learning 66th image
# Learning 67th image
# Learning 68th image
# Learning 69th image
# Learning 70th image
# Learning 71th image
# Learning 72th image
# Learning 73th image
# Learning 74th image
# Learning 75th image
# Learning 76th image
# Learning 77th image
# Learning 78th image
# Learning 79th image
# Learning 80th image
# Learning 81th image
# Learning 82th image
# Learning 83th image
# Learning 84th image
# Learning 85th image
# Learning 86th image
# Learning 87th image
# Learning 88th image
# Learning 89th image
# Learning 90th image
# Learning 91th image
# Learning 92th image
# Learning 93th image
# Learning 94th image
# Learning 95th image
# Learning 96th image
# Learning 97th image
# Learning 98th image
# Learning 99th image
# Learning 100th image
# Learning 101th image
# Learning 102th image
# Learning 103th image
# Learning 104th image
# Learning 105th image
# Learning 106th image
# Learning 107th image
# Learning 108th image
# Learning 109th image
# Learning 110th image
# Learning 111th image
# Learning 112th image
# Learning 113th image
# Learning 114th image
# Learning 115th image
# Learning 116th image
# Learning 117th image
# Learning 118th image
# Learning 119th image
# Learning 120th image
# Learning 121th image
# Learning 122th image
# Learning 123th image
# Learning 124th image
# Learning 125th image
# Learning 126th image
# Learning 127th image
# Learning 128th image
# Learning 129th image
# Learning 130th image
# Learning 131th image
# Learning 132th image
# Learning 133th image
# Learning 134th image
# Learning 135th image
# Learning 136th image
# Learning 137th image
# Learning 138th image
# Learning 139th image
# Learning 140th image
# Learning 141th image
# Learning 142th image
# Learning 143th image
# Learning 144th image
# Learning 145th image
# Learning 146th image
# Learning 147th image
# Learning 148th image
# Learning 149th image
# Learning 150th image
# Learning 151th image
# Learning 152th image
# Learning 153th image
# Learning 154th image
# Learning 155th image
# Learning 156th image
# Learning 157th image
# Learning 158th image
# Learning 159th image
# Learning 160th image
# Learning 161th image
# Learning 162th image
# Learning 163th image
# Learning 164th image
# Learning 165th image
# Learning 166th image
# Learning 167th image
# Learning 168th image
# Learning 169th image
# Learning 170th image
# Learning 171th image
# Learning 172th image
# Learning 173th image
# Learning 174th image
# Learning 175th image
# Learning 176th image
# Learning 177th image
# Learning 178th image
# Learning 179th image
# Learning 180th image
# Learning 181th image
# Learning 182th image
# Learning 183th image
# Learning 184th image
# Learning 185th image
# Learning 186th image
# Learning 187th image
# Learning 188th image
# Learning 189th image
# Learning 190th image
# Learning 191th image
# Learning 192th image
# Learning 193th image
# Learning 194th image
# Learning 195th image
# Learning 196th image
# Learning 197th image
# Learning 198th image
# Learning 199th image
# Learning 200th image
# Learning 201th image
# Learning 202th image
# Learning 203th image
# Learning 204th image
# Learning 205th image
# Learning 206th image
# Learning 207th image
# Learning 208th image
# Learning 209th image
# Learning 210th image
# Learning 211th image
# Learning 212th image
# Learning 213th image
# Learning 214th image
# Learning 215th image
# Learning 216th image
# Learning 217th image
# Learning 218th image
# Learning 219th image
# Learning 220th image
# Learning 221th image
# Learning 222th image
# Learning 223th image
# Learning 224th image
# Learning 225th image
# Learning 226th image
# Learning 227th image
# Learning 228th image
# Learning 229th image
# Learning 230th image
# Learning 231th image
# Learning 232th image
# Learning 233th image
# Learning 234th image
# Learning 235th image
# Learning 236th image
# Learning 237th image
# Learning 238th image
# Learning 239th image
# Learning 240th image
# Learning 241th image
# Learning 242th image
# Learning 243th image
# Learning 244th image
# Learning 245th image
# Learning 246th image
# Learning 247th image
# Learning 248th image
# Learning 249th image
# Learning 250th image
# Learning 251th image
# Learning 252th image
# Learning 253th image
# Learning 254th image
# Learning 255th image
# Learning 256th image
# Learning 257th image
# Learning 258th image
# Learning 259th image
# Learning 260th image
# Learning 261th image
# Learning 262th image
# Learning 263th image
# Learning 264th image
# Learning 265th image
# Learning 266th image
# Learning 267th image
# Learning 268th image
# Learning 269th image
# Learning 270th image
# Learning 271th image
# Learning 272th image
# Learning 273th image
# Completed Learning
#
# Stats
#
# True Positives:  285
# True Negatives:  313
# False Positives:  231
# False Negatives:  259
# Accuracy:  0.55
# Precision:  0.55
# Recall:  0.52
# FAR:  0.42
# FRR:  0.48
# F1 score:  0.54

# %% [markdown]
# ##### SVM

# %%
clf = svm.SVC()
run(clsf)
# Out:
# Learning 1th image
# Learning 2th image
# Learning 3th image
# Learning 4th image
# Learning 5th image
# Learning 6th image
# Learning 7th image
# Learning 8th image
# Learning 9th image
# Learning 10th image
# Learning 11th image
# Learning 12th image
# Learning 13th image
# Learning 14th image
# Learning 15th image
# Learning 16th image
# Learning 17th image
# Learning 18th image
# Learning 19th image
# Learning 20th image
# Learning 21th image
# Learning 22th image
# Learning 23th image
# Learning 24th image
# Learning 25th image
# Learning 26th image
# Learning 27th image
# Learning 28th image
# Learning 29th image
# Learning 30th image
# Learning 31th image
# Learning 32th image
# Learning 33th image
# Learning 34th image
# Learning 35th image
# Learning 36th image
# Learning 37th image
# Learning 38th image
# Learning 39th image
# Learning 40th image
# Learning 41th image
# Learning 42th image
# Learning 43th image
# Learning 44th image
# Learning 45th image
# Learning 46th image
# Learning 47th image
# Learning 48th image
# Learning 49th image
# Learning 50th image
# Learning 51th image
# Learning 52th image
# Learning 53th image
# Learning 54th image
# Learning 55th image
# Learning 56th image
# Learning 57th image
# Learning 58th image
# Learning 59th image
# Learning 60th image
# Learning 61th image
# Learning 62th image
# Learning 63th image
# Learning 64th image
# Learning 65th image
# Learning 66th image
# Learning 67th image
# Learning 68th image
# Learning 69th image
# Learning 70th image
# Learning 71th image
# Learning 72th image
# Learning 73th image
# Learning 74th image
# Learning 75th image
# Learning 76th image
# Learning 77th image
# Learning 78th image
# Learning 79th image
# Learning 80th image
# Learning 81th image
# Learning 82th image
# Learning 83th image
# Learning 84th image
# Learning 85th image
# Learning 86th image
# Learning 87th image
# Learning 88th image
# Learning 89th image
# Learning 90th image
# Learning 91th image
# Learning 92th image
# Learning 93th image
# Learning 94th image
# Learning 95th image
# Learning 96th image
# Learning 97th image
# Learning 98th image
# Learning 99th image
# Learning 100th image
# Learning 101th image
# Learning 102th image
# Learning 103th image
# Learning 104th image
# Learning 105th image
# Learning 106th image
# Learning 107th image
# Learning 108th image
# Learning 109th image
# Learning 110th image
# Learning 111th image
# Learning 112th image
# Learning 113th image
# Learning 114th image
# Learning 115th image
# Learning 116th image
# Learning 117th image
# Learning 118th image
# Learning 119th image
# Learning 120th image
# Learning 121th image
# Learning 122th image
# Learning 123th image
# Learning 124th image
# Learning 125th image
# Learning 126th image
# Learning 127th image
# Learning 128th image
# Learning 129th image
# Learning 130th image
# Learning 131th image
# Learning 132th image
# Learning 133th image
# Learning 134th image
# Learning 135th image
# Learning 136th image
# Learning 137th image
# Learning 138th image
# Learning 139th image
# Learning 140th image
# Learning 141th image
# Learning 142th image
# Learning 143th image
# Learning 144th image
# Learning 145th image
# Learning 146th image
# Learning 147th image
# Learning 148th image
# Learning 149th image
# Learning 150th image
# Learning 151th image
# Learning 152th image
# Learning 153th image
# Learning 154th image
# Learning 155th image
# Learning 156th image
# Learning 157th image
# Learning 158th image
# Learning 159th image
# Learning 160th image
# Learning 161th image
# Learning 162th image
# Learning 163th image
# Learning 164th image
# Learning 165th image
# Learning 166th image
# Learning 167th image
# Learning 168th image
# Learning 169th image
# Learning 170th image
# Learning 171th image
# Learning 172th image
# Learning 173th image
# Learning 174th image
# Learning 175th image
# Learning 176th image
# Learning 177th image
# Learning 178th image
# Learning 179th image
# Learning 180th image
# Learning 181th image
# Learning 182th image
# Learning 183th image
# Learning 184th image
# Learning 185th image
# Learning 186th image
# Learning 187th image
# Learning 188th image
# Learning 189th image
# Learning 190th image
# Learning 191th image
# Learning 192th image
# Learning 193th image
# Learning 194th image
# Learning 195th image
# Learning 196th image
# Learning 197th image
# Learning 198th image
# Learning 199th image
# Learning 200th image
# Learning 201th image
# Learning 202th image
# Learning 203th image
# Learning 204th image
# Learning 205th image
# Learning 206th image
# Learning 207th image
# Learning 208th image
# Learning 209th image
# Learning 210th image
# Learning 211th image
# Learning 212th image
# Learning 213th image
# Learning 214th image
# Learning 215th image
# Learning 216th image
# Learning 217th image
# Learning 218th image
# Learning 219th image
# Learning 220th image
# Learning 221th image
# Learning 222th image
# Learning 223th image
# Learning 224th image
# Learning 225th image
# Learning 226th image
# Learning 227th image
# Learning 228th image
# Learning 229th image
# Learning 230th image
# Learning 231th image
# Learning 232th image
# Learning 233th image
# Learning 234th image
# Learning 235th image
# Learning 236th image
# Learning 237th image
# Learning 238th image
# Learning 239th image
# Learning 240th image
# Learning 241th image
# Learning 242th image
# Learning 243th image
# Learning 244th image
# Learning 245th image
# Learning 246th image
# Learning 247th image
# Learning 248th image
# Learning 249th image
# Learning 250th image
# Learning 251th image
# Learning 252th image
# Learning 253th image
# Learning 254th image
# Learning 255th image
# Learning 256th image
# Learning 257th image
# Learning 258th image
# Learning 259th image
# Learning 260th image
# Learning 261th image
# Learning 262th image
# Learning 263th image
# Learning 264th image
# Learning 265th image
# Learning 266th image
# Learning 267th image
# Learning 268th image
# Learning 269th image
# Learning 270th image
# Learning 271th image
# Learning 272th image
# Learning 273th image
# Completed Learning
#
# Stats
#
# True Positives:  253
# True Negatives:  335
# False Positives:  209
# False Negatives:  291
# Accuracy:  0.54
# Precision:  0.55
# Recall:  0.47
# FAR:  0.38
# FRR:  0.53
# F1 score:  0.5
